# %%
from datetime import datetime
from importlib import reload

import vnpy_portfoliostrategy

from ztp.strategies.etf_rotation_strategy import ETFRotationStrategy

reload(vnpy_portfoliostrategy)

from vnpy_portfoliostrategy import BacktestingEngine
from vnpy.trader.constant import Interval

if __name__ == '__main__':
    symbols = ['XLK.NYSE',
               'XLF.NYSE',
               'XLV.NYSE',
               'XLE.NYSE',
               'XLY.NYSE',
               'XLP.NYSE',
               'XLI.NYSE',
               'XLB.NYSE',
               'XLU.NYSE']
    rate = 2 / 10000
    slippage = 0
    size = 1
    pricetick = 0.001

    rates = {symbol: rate for symbol in symbols}
    slippages = {symbol: slippage for symbol in symbols}
    sizes = {symbol: size for symbol in symbols}
    priceticks = {symbol: pricetick for symbol in symbols}

    engine = BacktestingEngine()

    engine.set_parameters(
        vt_symbols=symbols,
        interval=Interval.DAILY,
        start=datetime(2019, 1, 1),
        end=datetime(2022, 4, 30),
        # 每种vt_symbol的手续费率
        rates=rates,
        # 每种vt_symbol的滑点
        slippages=slippages,
        # 每种vt_symbol每手volume等于多少数量，实际下单数量=volume*size
        sizes=sizes,
        # 每种vt_symbol的价格数值格式，例如 1=取整，0.01=保留两位小数
        priceticks=priceticks,
        capital=1_000_000,
    )

    setting = {
    }
    engine.add_strategy(ETFRotationStrategy, setting)

    engine.load_data()
    engine.run_backtesting()
    df = engine.calculate_result()
    engine.calculate_statistics()
    engine.get_all_trades()
    engine.show_chart()
# Out:
# 2025-03-06 01:00:15.419684	Start loading historical data
# 2025-03-06 01:00:15.606801	Historical data loading completed, data count: XLK.NYSE
# 2025-03-06 01:00:15.671709	Historical data loading completed, data count: XLF.NYSE
# 2025-03-06 01:00:15.748952	Historical data loading completed, data count: XLV.NYSE
# 2025-03-06 01:00:15.818783	Historical data loading completed, data count: XLE.NYSE
# 2025-03-06 01:00:15.890204	Historical data loading completed, data count: XLY.NYSE
# 2025-03-06 01:00:15.973763	Historical data loading completed, data count: XLP.NYSE
# 2025-03-06 01:00:16.141114	Historical data loading completed, data count: XLI.NYSE
# 2025-03-06 01:00:16.212440	Historical data loading completed, data count: XLB.NYSE
# 2025-03-06 01:00:16.271620	Historical data loading completed, data count: XLU.NYSE
# 2025-03-06 01:00:16.271660	All historical data has been loaded
# 2025-03-06 01:00:16.272671	Strategy initialization complete
# 2025-03-06 01:00:16.272714	Start replaying historical data
# 2025-03-06 01:00:16.412433	Historical backtest complete
# 2025-03-06 01:00:16.412615	Start calculating daily mark-to-market profit and loss
# 2025-03-06 01:00:16.412630	Failed to calculate strategy statistical indicators due to empty trade records
# 2025-03-06 01:00:16.412641	Start calculating strategy statistical indicators
# 2025-03-06 01:00:16.412651	------------------------------
# 2025-03-06 01:00:16.412661	Start Date:
# 2025-03-06 01:00:16.412670	End Date:
# 2025-03-06 01:00:16.412679	Total Days: 	0
# 2025-03-06 01:00:16.412688	Profit Days: 	0
# 2025-03-06 01:00:16.412697	Loss Days: 	0
# 2025-03-06 01:00:16.412710	Capital: 	1,000,000.00
# 2025-03-06 01:00:16.412720	End Balance: 	0.00
# 2025-03-06 01:00:16.412730	Total Return: 	0.00%
# 2025-03-06 01:00:16.412739	Annual Return: 	0.00%
# 2025-03-06 01:00:16.412748	Max Drawdown: 	0.00
# 2025-03-06 01:00:16.412757	Max Ddpercent: 0.00%
# 2025-03-06 01:00:16.412765	Max Drawdown Duration: 	0
# 2025-03-06 01:00:16.412774	Total Net P&L: 	0.00
# 2025-03-06 01:00:16.412783	Total Commission: 	0.00
# 2025-03-06 01:00:16.412792	Total Slippage: 	0.00
# 2025-03-06 01:00:16.412801	Total Turnover: 	0.00
# 2025-03-06 01:00:16.412810	Total Trade Count: 	0
# 2025-03-06 01:00:16.412818	Daily Net P&L: 	0.00
# 2025-03-06 01:00:16.412827	Daily Commission: 	0.00
# 2025-03-06 01:00:16.412836	Daily Slippage: 	0.00
# 2025-03-06 01:00:16.412845	Daily Turnover: 	0.00
# 2025-03-06 01:00:16.412853	Daily Trade Count: 	0
# 2025-03-06 01:00:16.412862	Daily Return: 	0.00%
# 2025-03-06 01:00:16.412871	Return Std: 	0.00%
# 2025-03-06 01:00:16.412881	Sharpe Ratio：	0.00
# 2025-03-06 01:00:16.412890	Return Drawdown Ratio: 	0.00
# 2025-03-06 01:00:16.412961	Strategy statistical indicators calculation completed
